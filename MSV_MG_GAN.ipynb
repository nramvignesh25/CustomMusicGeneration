# %%
cd '/content/drive/MyDrive/MSVMG/Models'
# Out:
# /content/drive/MyDrive/MSVMG/Models

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/MSVMG/Models'

# %%
ls
# Out:
#  archive/                    GAN_Loss_per_Epoch_final.png   MSV_MG_GAN.ipynb     __pycache__/
#  create_generator_model.py   generated_music.mid            MSV_MG_GPT2.ipynb
#  discriminator_model.h5      generate_music.py              MSV_MIDI_Songs/
#  gan_final.mid               generator_model.h5            'Output Generated'/

# %%
pip install tensorflow keras music21

# %%
# !python /content/drive/MyDrive/MSVMG/Models/create_generator_model.py
# Out:
# 2023-11-21 10:51:16.438911: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 10:51:16.438976: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 10:51:16.439019: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 10:51:16.448238: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python /content/drive/MyDrive/MSVMG/Models/generate_music.py
# Out:
# 2023-11-21 10:52:49.651678: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 10:52:49.651739: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 10:52:49.651767: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 10:52:49.659982: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
